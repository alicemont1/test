# %% [markdown]
# ## Polytope Climate-DT example notebook
#
# This notebook shows how to use earthkit-data and earthkit-plots to pull destination-earth data from LUMI and plot it using earthkit-plots. Specifically this notebook shows how to do server side interpolation to a healpix grid.
#
# Before running the notebook you need to set up your credentials. See the main readme of this repository for different ways to do this or use the following cells to authenticate.
#
# You will need to generate your credentials using the desp-authentication.py script.
#
# This can be run as follows:

# %%
# %%capture cap
# %run ../desp-authentication.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_latest/lib/python3.13/site-packages/IPython/core/magics/execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     726     fpath = arg_lst[0]
# --> 727     filename = file_finder(fpath)
#     728 except IndexError as e:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_latest/lib/python3.13/site-packages/IPython/utils/path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'../desp-authentication.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', '../desp-authentication.py')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_latest/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2488, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2486     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2487 with self.builtin_trap:
# -> 2488     result = fn(*args, **kwargs)
#    2490 # The code below prevents the output from being displayed
#    2491 # when using magics with decorator @output_can_be_silenced
#    2492 # when the last Python token in the expression is a ';'.
#    2493 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_latest/lib/python3.13/site-packages/IPython/core/magics/execution.py:738, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     736     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     737         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 738     raise Exception(msg) from e
#     739 except TypeError:
#     740     if fpath in sys.meta_path:
#
# Exception: File `'../desp-authentication.py'` not found.

# %% [markdown]
# This will generate a token that can then be used by earthkit and polytope.

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %% [markdown]
# # Requirements
# To run this notebook install the following:
# * pip install earthkit-data
# * pip install earthkit-plots
# * pip install earthkit-regrid  (Optional for spectral variables)
# * pip install cf-units         (Optional for unit conversion in maps)
#
# If you do not have eccodes installed please install eccodes using conda as it is a dependency of earthkit, or install earthkit via conda
#
# * conda install eccodes -c conda-forge
# * conda install earthkit-data -c conda-forge

# %%
import earthkit.data
import earthkit.plots
import earthkit.regrid
from polytope.api import Client

# %%
client = Client(
    address="polytope.lumi.apps.dte.destination-earth.eu")

request = {
    'activity': 'scenariomip',
    'class': 'd1',
    'dataset': 'climate-dt',
    'date': '20300101',
    'time': "0000",
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    'generation': '1',
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '167',
    'realization': '1',
    'resolution': 'high',
    'stream': 'clte',
    'grid':'h16', # currently O, F, N, H grids are supported 
    'type': 'fc',
}

file = client.retrieve("destination-earth", request, "data/climate-dt-earthkit-healpix-interpolate.grib")
# Out:
# 2025-06-24 01:25:15 - INFO - Sending request...
# {'request': 'activity: scenariomip\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20300101'\n"
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             'grid: h16\n'
#             'levtype: sfc\n'
#             'model: IFS-NEMO\n'
#             "param: '167'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-06-24 01:25:17 - INFO - Request accepted. Please poll ./61bb4d1a-b9f0-4c3a-bd7c-2a139b9e8abe for status
# 2025-06-24 01:25:17 - INFO - Checking request status (./61bb4d1a-b9f0-4c3a-bd7c-2a139b9e8abe)...
# 2025-06-24 01:25:17 - INFO - The current status of the request is 'queued'
# 2025-06-24 01:25:18 - INFO - The current status of the request is 'processing'
# 2025-06-24 01:25:21 - INFO - The current status of the request is 'processed'
# 2025-06-24 01:25:21 - INFO - Starting data download (application/x-grib)...
# 2025-06-24 01:25:21 - INFO - Saving data into data/climate-dt-earthkit-healpix-interpolate.grib...
# 2025-06-24 01:25:21 - INFO - Data downloaded successfully
# 2025-06-24 01:25:21 - INFO - Download rate 585.5KiB/s
# 2025-06-24 01:25:21 - INFO - Data saved successfully into data/climate-dt-earthkit-healpix-interpolate.grib

# %%
data = earthkit.data.from_source("file", "data/climate-dt-earthkit-healpix-interpolate.grib")

# %%
data.ls()
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20300101         0         0
#
#   dataType number gridType
# 0       fc   None  healpix

# %%
data.to_xarray()
# Out:
# <xarray.Dataset> Size: 74kB
# Dimensions:    (values: 3072)
# Coordinates:
#     latitude   (values) float64 25kB ...
#     longitude  (values) float64 25kB ...
# Dimensions without coordinates: values
# Data variables:
#     2t         (values) float64 25kB ...
# Attributes:
#     param:        2t
#     paramId:      167
#     class:        d1
#     stream:       clte
#     levtype:      sfc
#     type:         fc
#     expver:       0001
#     date:         20300101
#     time:         0
#     Conventions:  CF-1.8
#     institution:  ECMWF

# %%
chart = earthkit.plots.Map(extent=[-180, 180, -90, 90])
chart.block(
    data
)

chart.title("Temperature")
chart.coastlines()
chart.gridlines()
chart.show()

# %%
a=2
